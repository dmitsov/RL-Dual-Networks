# %% [markdown]
# **Single Stream Test**

# %%
# # get the latest JAX and jaxlib
# !pip install --upgrade -q jax jaxlib

# # Colab runtime set to TPU accel
# import requests
# import os
# if 'TPU_DRIVER_MODE' not in globals():
#   url = 'http://' + os.environ['COLAB_TPU_ADDR'].split(':')[0] + ':8475/requestversion/tpu_driver_nightly'
#   resp = requests.post(url)
#   TPU_DRIVER_MODE = 1

# # TPU driver as backend for JAX
# from jax.config import config
# config.FLAGS.jax_xla_backend = "tpu_driver"
# config.FLAGS.jax_backend_target = "grpc://" + os.environ['COLAB_TPU_ADDR']
# print(config.FLAGS.jax_backend_target)

# %%
import os
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content
DRIVE_PATH = '/content/gdrive/My\ Drive/DL-Agent'
DRIVE_PYTHON_PATH = DRIVE_PATH.replace('\\', '')
if not os.path.exists(DRIVE_PYTHON_PATH):
  # %mkdir $DRIVE_PATH


## the space in `My Drive` causes some issues,
## make a symlink to avoid this
SYM_PATH = '/content/DL-Agent'
if not os.path.exists(SYM_PATH):
  # !ln -s $DRIVE_PATH $SYM_PATH

# %cd $SYM_PATH
# Out:
# /content
# /content/gdrive/My Drive/DL-Agent

# %%
# !apt update 
# !apt install -y --no-install-recommends \
        build-essential \
        curl \
        git \
        gnupg2 \
        make \
        cmake \
        ffmpeg \
        swig \
        libz-dev \
        unzip \
        zlib1g-dev \
        libglfw3 \
        libglfw3-dev \
        libxrandr2 \
        libxinerama-dev \
        libxi6 \
        libxcursor-dev \
        libgl1-mesa-dev \
        libgl1-mesa-glx \
        libglew-dev \
        libosmesa6-dev \
        lsb-release \
        ack-grep \
        patchelf \
        wget \
        xpra \
        xserver-xorg-dev \
        xvfb \
        python-opengl \
        ffmpeg > /dev/null 2>&1

# !pip install opencv-python==3.4.0.12
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:2 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:3 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Hit:5 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Ign:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:10 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,715 kB]
# Ign:11 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Hit:13 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:14 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:15 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [878 kB]
# Get:16 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,381 kB]
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [1,890 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,148 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,310 kB]
# Ign:21 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages
# Get:21 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [548 kB]
# Fetched 11.1 MB in 2s (4,965 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 50 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Collecting opencv-python==3.4.0.12
#   Downloading https://files.pythonhosted.org/packages/50/f9/5c454f0f52788a913979877e6ed9b2454a9c7676581a0ee3a2d81db784a6/opencv_python-3.4.0.12-cp36-cp36m-manylinux1_x86_64.whl (24.9MB)
#      |████████████████████████████████| 24.9MB 140kB/s
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from opencv-python==3.4.0.12) (1.19.5)
# ERROR: dopamine-rl 1.0.5 has requirement opencv-python>=3.4.1.15, but you'll have opencv-python 3.4.0.12 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: opencv-python
#   Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
# Successfully installed opencv-python-3.4.0.12

# %%
# %pip install -r requirements_colab.txt 
video_path = os.path.join(SYM_PATH, 'video')
os.chdir(SYM_PATH)
# !pwd

required_files = ['AtariWrappers.py', 
                  'ReplayBuffer.py', 'DL_Agent.py', 
                  'EnvironmentUtility.py', 
                  'DDQN.py',
                  'Logger.py',
                  'PolicyUtility.py']
for f in required_files:
  assert os.path.isfile(f)
# Out:
# Collecting gym[atari]==0.17.2
#   Downloading https://files.pythonhosted.org/packages/b3/99/7cc3e510678119cdac91f33fb9235b98448f09a6bdf0cafea2b108d9ce51/gym-0.17.2.tar.gz (1.6MB)
#      |████████████████████████████████| 1.6MB 12.9MB/s
# Collecting pyvirtualdisplay==1.3.2
#   Downloading https://files.pythonhosted.org/packages/d0/8a/643043cc70791367bee2d19eb20e00ed1a246ac48e5dbe57bbbcc8be40a9/PyVirtualDisplay-1.3.2-py2.py3-none-any.whl
# Collecting box2d-py
#   Downloading https://files.pythonhosted.org/packages/06/bd/6cdc3fd994b0649dcf5d9bad85bd9e26172308bbe9a421bfc6fdbf5081a6/box2d_py-2.3.8-cp36-cp36m-manylinux1_x86_64.whl (448kB)
#      |████████████████████████████████| 450kB 48.3MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym[atari]==0.17.2->-r requirements_colab.txt (line 1)) (1.4.1)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.6/dist-packages (from gym[atari]==0.17.2->-r requirements_colab.txt (line 1)) (1.19.5)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from gym[atari]==0.17.2->-r requirements_colab.txt (line 1)) (1.5.0)
# Requirement already satisfied: cloudpickle<1.4.0,>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym[atari]==0.17.2->-r requirements_colab.txt (line 1)) (1.3.0)
# Requirement already satisfied: atari_py~=0.2.0 in /usr/local/lib/python3.6/dist-packages (from gym[atari]==0.17.2->-r requirements_colab.txt (line 1)) (0.2.6)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from gym[atari]==0.17.2->-r requirements_colab.txt (line 1)) (7.0.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.6/dist-packages (from gym[atari]==0.17.2->-r requirements_colab.txt (line 1)) (3.4.0.12)
# Collecting EasyProcess
#   Downloading https://files.pythonhosted.org/packages/48/3c/75573613641c90c6d094059ac28adb748560d99bd27ee6f80cce398f404e/EasyProcess-0.3-py2.py3-none-any.whl
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym[atari]==0.17.2->-r requirements_colab.txt (line 1)) (0.16.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from atari_py~=0.2.0->gym[atari]==0.17.2->-r requirements_colab.txt (line 1)) (1.15.0)
# Building wheels for collected packages: gym
#   Building wheel for gym (setup.py) ... done
#   Created wheel for gym: filename=gym-0.17.2-cp36-none-any.whl size=1650891 sha256=17bc943abfed629259f720a94754f7b422859710a17703ceb4a1d8f36f760a58
#   Stored in directory: /root/.cache/pip/wheels/87/e0/91/f56e44e8062f8cd549673da49f59e1d4fe8b17398119b1d221
# Successfully built gym
# ERROR: dopamine-rl 1.0.5 has requirement opencv-python>=3.4.1.15, but you'll have opencv-python 3.4.0.12 which is incompatible.
# Installing collected packages: gym, EasyProcess, pyvirtualdisplay, box2d-py
#   Found existing installation: gym 0.17.3
#     Uninstalling gym-0.17.3:
#       Successfully uninstalled gym-0.17.3
# Successfully installed EasyProcess-0.3 box2d-py-2.3.8 gym-0.17.2 pyvirtualdisplay-1.3.2
# /content/gdrive/My Drive/DL-Agent

# %%
from DL_Agent import runLearning


runLearning(True,['params_v4'], SYM_PATH)
# Out:
# Streaming output truncated to the last 5000 lines.
# best mean reward (ever) 552.030000.
# episode # 2276.
# exploration eps 0.001000.
# running time 0.112067
# ------------------------------
#
# ------------------------------
# Timestep 3404282.
# mean reward (over 100 episodes) 244.150000.
# best mean reward (ever) 552.030000.
# episode # 2277.
# exploration eps 0.001000.
# running time 0.113393
# ------------------------------
#
# ------------------------------
# Timestep 3405384.
# mean reward (over 100 episodes) 241.160000.
# best mean reward (ever) 552.030000.
# episode # 2278.
# exploration eps 0.001000.
# running time 0.111512
# ------------------------------
#
# ------------------------------
# Timestep 3406477.
# mean reward (over 100 episodes) 241.150000.
# best mean reward (ever) 552.030000.
# episode # 2279.
# exploration eps 0.001000.
# running time 0.110501
# ------------------------------
#
# ------------------------------
# Timestep 3407583.
# mean reward (over 100 episodes) 238.130000.
# best mean reward (ever) 552.030000.
# episode # 2280.
# exploration eps 0.001000.
# running time 0.111899
# ------------------------------
#
# ------------------------------
# Timestep 3408678.
# mean reward (over 100 episodes) 238.080000.
# best mean reward (ever) 552.030000.
# episode # 2281.
# exploration eps 0.001000.
# running time 0.110908
# ------------------------------
#
# ------------------------------
# Timestep 3409778.
# mean reward (over 100 episodes) 238.140000.
# best mean reward (ever) 552.030000.
# episode # 2282.
# exploration eps 0.001000.
# running time 0.111454
# ------------------------------
#
# ------------------------------
# Timestep 3410884.
# mean reward (over 100 episodes) 238.130000.
# best mean reward (ever) 552.030000.
# episode # 2283.
# exploration eps 0.001000.
# running time 0.112624
# ------------------------------
#
# ------------------------------
# Timestep 3413096.
# mean reward (over 100 episodes) 240.900000.
# best mean reward (ever) 552.030000.
# episode # 2284.
# exploration eps 0.001000.
# running time 0.224237
# ------------------------------
#
# ------------------------------
# Timestep 3414209.
# mean reward (over 100 episodes) 240.900000.
# best mean reward (ever) 552.030000.
# episode # 2285.
# exploration eps 0.001000.
# running time 0.113146
# ------------------------------
#
# ------------------------------
# Timestep 3415313.
# mean reward (over 100 episodes) 240.940000.
# best mean reward (ever) 552.030000.
# episode # 2286.
# exploration eps 0.001000.
# running time 0.113421
# ------------------------------
#
# ------------------------------
# Timestep 3416417.
# mean reward (over 100 episodes) 240.910000.
# best mean reward (ever) 552.030000.
# episode # 2287.
# exploration eps 0.001000.
# running time 0.111378
# ------------------------------
#
# ------------------------------
# Timestep 3417525.
# mean reward (over 100 episodes) 240.910000.
# best mean reward (ever) 552.030000.
# episode # 2288.
# exploration eps 0.001000.
# running time 0.112740
# ------------------------------
#
# ------------------------------
# Timestep 3418638.
# mean reward (over 100 episodes) 240.910000.
# best mean reward (ever) 552.030000.
# episode # 2289.
# exploration eps 0.001000.
# running time 0.112486
# ------------------------------
#
# ------------------------------
# Timestep 3419739.
# mean reward (over 100 episodes) 240.950000.
# best mean reward (ever) 552.030000.
# episode # 2290.
# exploration eps 0.001000.
# running time 0.111476
# ------------------------------
#
# ------------------------------
# Timestep 3420836.
# mean reward (over 100 episodes) 240.920000.
# best mean reward (ever) 552.030000.
# episode # 2291.
# exploration eps 0.001000.
# running time 0.111627
# ------------------------------
#
# ------------------------------
# Timestep 3421941.
# mean reward (over 100 episodes) 240.890000.
# best mean reward (ever) 552.030000.
# episode # 2292.
# exploration eps 0.001000.
# running time 0.112201
# ------------------------------
#
# ------------------------------
# Timestep 3423042.
# mean reward (over 100 episodes) 240.920000.
# best mean reward (ever) 552.030000.
# episode # 2293.
# exploration eps 0.001000.
# running time 0.111280
# ------------------------------
#
# ------------------------------
# Timestep 3424150.
# mean reward (over 100 episodes) 240.900000.
# best mean reward (ever) 552.030000.
# episode # 2294.
# exploration eps 0.001000.
# running time 0.111982
# ------------------------------
#
# ------------------------------
# Timestep 3425257.
# mean reward (over 100 episodes) 240.910000.
# best mean reward (ever) 552.030000.
# episode # 2295.
# exploration eps 0.001000.
# running time 0.111364
# ------------------------------
#
# ------------------------------
# Timestep 3426357.
# mean reward (over 100 episodes) 240.880000.
# best mean reward (ever) 552.030000.
# episode # 2296.
# exploration eps 0.001000.
# running time 0.112112
# ------------------------------
#
# ------------------------------
# Timestep 3427455.
# mean reward (over 100 episodes) 240.850000.
# best mean reward (ever) 552.030000.
# episode # 2297.
# exploration eps 0.001000.
# running time 0.111492
# ------------------------------
#
# ------------------------------
# Timestep 3428563.
# mean reward (over 100 episodes) 240.880000.
# best mean reward (ever) 552.030000.
# episode # 2298.
# exploration eps 0.001000.
# running time 0.112971
# ------------------------------
#
# ------------------------------
# Timestep 3429672.
# mean reward (over 100 episodes) 240.880000.
# best mean reward (ever) 552.030000.
# episode # 2299.
# exploration eps 0.001000.
# running time 0.112179
# ------------------------------
#
# ------------------------------
# Timestep 3430782.
# mean reward (over 100 episodes) 240.990000.
# best mean reward (ever) 552.030000.
# episode # 2300.
# exploration eps 0.001000.
# running time 0.112886
# ------------------------------
#
# ------------------------------
# Timestep 3431892.
# mean reward (over 100 episodes) 240.990000.
# best mean reward (ever) 552.030000.
# episode # 2301.
# exploration eps 0.001000.
# running time 0.113979
# ------------------------------
#
# ------------------------------
# Timestep 3432985.
# mean reward (over 100 episodes) 241.010000.
# best mean reward (ever) 552.030000.
# episode # 2302.
# exploration eps 0.001000.
# running time 0.110697
# ------------------------------
#
# ------------------------------
# Timestep 3434088.
# mean reward (over 100 episodes) 241.020000.
# best mean reward (ever) 552.030000.
# episode # 2303.
# exploration eps 0.001000.
# running time 0.114445
# ------------------------------
#
# ------------------------------
# Timestep 3435206.
# mean reward (over 100 episodes) 241.010000.
# best mean reward (ever) 552.030000.
# episode # 2304.
# exploration eps 0.001000.
# running time 0.113019
# ------------------------------
#
# ------------------------------
# Timestep 3436311.
# mean reward (over 100 episodes) 241.000000.
# best mean reward (ever) 552.030000.
# episode # 2305.
# exploration eps 0.001000.
# running time 0.112024
# ------------------------------
#
# ------------------------------
# Timestep 3437412.
# mean reward (over 100 episodes) 238.120000.
# best mean reward (ever) 552.030000.
# episode # 2306.
# exploration eps 0.001000.
# running time 0.112463
# ------------------------------
#
# ------------------------------
# Timestep 3438527.
# mean reward (over 100 episodes) 238.140000.
# best mean reward (ever) 552.030000.
# episode # 2307.
# exploration eps 0.001000.
# running time 0.112317
# ------------------------------
#
# ------------------------------
# Timestep 3439633.
# mean reward (over 100 episodes) 238.160000.
# best mean reward (ever) 552.030000.
# episode # 2308.
# exploration eps 0.001000.
# running time 0.112054
# ------------------------------
#
# ------------------------------
# Timestep 3440741.
# mean reward (over 100 episodes) 238.140000.
# best mean reward (ever) 552.030000.
# episode # 2309.
# exploration eps 0.001000.
# running time 0.111550
# ------------------------------
#
# ------------------------------
# Timestep 3441844.
# mean reward (over 100 episodes) 238.130000.
# best mean reward (ever) 552.030000.
# episode # 2310.
# exploration eps 0.001000.
# running time 0.113883
# ------------------------------
#
# ------------------------------
# Timestep 3442945.
# mean reward (over 100 episodes) 238.180000.
# best mean reward (ever) 552.030000.
# episode # 2311.
# exploration eps 0.001000.
# running time 0.111504
# ------------------------------
#
# ------------------------------
# Timestep 3445161.
# mean reward (over 100 episodes) 241.040000.
# best mean reward (ever) 552.030000.
# episode # 2312.
# exploration eps 0.001000.
# running time 0.225776
# ------------------------------
#
# ------------------------------
# Timestep 3446266.
# mean reward (over 100 episodes) 241.080000.
# best mean reward (ever) 552.030000.
# episode # 2313.
# exploration eps 0.001000.
# running time 0.112390
# ------------------------------
#
# ------------------------------
# Timestep 3447369.
# mean reward (over 100 episodes) 241.100000.
# best mean reward (ever) 552.030000.
# episode # 2314.
# exploration eps 0.001000.
# running time 0.112275
# ------------------------------
#
# ------------------------------
# Timestep 3448476.
# mean reward (over 100 episodes) 241.090000.
# best mean reward (ever) 552.030000.
# episode # 2315.
# exploration eps 0.001000.
# running time 0.111668
# ------------------------------
#
# ------------------------------
# Timestep 3450686.
# mean reward (over 100 episodes) 243.830000.
# best mean reward (ever) 552.030000.
# episode # 2316.
# exploration eps 0.001000.
# running time 0.222316
# ------------------------------
#
# ------------------------------
# Timestep 3451797.
# mean reward (over 100 episodes) 243.840000.
# best mean reward (ever) 552.030000.
# episode # 2317.
# exploration eps 0.001000.
# running time 0.112752
# ------------------------------
#
# ------------------------------
# Timestep 3452916.
# mean reward (over 100 episodes) 243.850000.
# best mean reward (ever) 552.030000.
# episode # 2318.
# exploration eps 0.001000.
# running time 0.114461
# ------------------------------
#
# ------------------------------
# Timestep 3454007.
# mean reward (over 100 episodes) 243.890000.
# best mean reward (ever) 552.030000.
# episode # 2319.
# exploration eps 0.001000.
# running time 0.110212
# ------------------------------
#
# ------------------------------
# Timestep 3455105.
# mean reward (over 100 episodes) 243.850000.
# best mean reward (ever) 552.030000.
# episode # 2320.
# exploration eps 0.001000.
# running time 0.110760
# ------------------------------
#
# ------------------------------
# Timestep 3457320.
# mean reward (over 100 episodes) 246.860000.
# best mean reward (ever) 552.030000.
# episode # 2321.
# exploration eps 0.001000.
# running time 0.224785
# ------------------------------
#
# ------------------------------
# Timestep 3458425.
# mean reward (over 100 episodes) 246.860000.
# best mean reward (ever) 552.030000.
# episode # 2322.
# exploration eps 0.001000.
# running time 0.111641
# ------------------------------
#
# ------------------------------
# Timestep 3459525.
# mean reward (over 100 episodes) 246.840000.
# best mean reward (ever) 552.030000.
# episode # 2323.
# exploration eps 0.001000.
# running time 0.110547
# ------------------------------
#
# ------------------------------
# Timestep 3460619.
# mean reward (over 100 episodes) 246.870000.
# best mean reward (ever) 552.030000.
# episode # 2324.
# exploration eps 0.001000.
# running time 0.111964
# ------------------------------
#
# ------------------------------
# Timestep 3461726.
# mean reward (over 100 episodes) 244.160000.
# best mean reward (ever) 552.030000.
# episode # 2325.
# exploration eps 0.001000.
# running time 0.112104
# ------------------------------
#
# ------------------------------
# Timestep 3462837.
# mean reward (over 100 episodes) 244.170000.
# best mean reward (ever) 552.030000.
# episode # 2326.
# exploration eps 0.001000.
# running time 0.112427
# ------------------------------
#
# ------------------------------
# Timestep 3463946.
# mean reward (over 100 episodes) 244.170000.
# best mean reward (ever) 552.030000.
# episode # 2327.
# exploration eps 0.001000.
# running time 0.111940
# ------------------------------
#
# ------------------------------
# Timestep 3465039.
# mean reward (over 100 episodes) 244.170000.
# best mean reward (ever) 552.030000.
# episode # 2328.
# exploration eps 0.001000.
# running time 0.110455
# ------------------------------
#
# ------------------------------
# Timestep 3466140.
# mean reward (over 100 episodes) 244.210000.
# best mean reward (ever) 552.030000.
# episode # 2329.
# exploration eps 0.001000.
# running time 0.111090
# ------------------------------
#
# ------------------------------
# Timestep 3467244.
# mean reward (over 100 episodes) 244.180000.
# best mean reward (ever) 552.030000.
# episode # 2330.
# exploration eps 0.001000.
# running time 0.111423
# ------------------------------
#
# ------------------------------
# Timestep 3468345.
# mean reward (over 100 episodes) 240.500000.
# best mean reward (ever) 552.030000.
# episode # 2331.
# exploration eps 0.001000.
# running time 0.112442
# ------------------------------
#
# ------------------------------
# Timestep 3469451.
# mean reward (over 100 episodes) 237.510000.
# best mean reward (ever) 552.030000.
# episode # 2332.
# exploration eps 0.001000.
# running time 0.111151
# ------------------------------
#
# ------------------------------
# Timestep 3470555.
# mean reward (over 100 episodes) 237.520000.
# best mean reward (ever) 552.030000.
# episode # 2333.
# exploration eps 0.001000.
# running time 0.111937
# ------------------------------
#
# ------------------------------
# Timestep 3471669.
# mean reward (over 100 episodes) 237.490000.
# best mean reward (ever) 552.030000.
# episode # 2334.
# exploration eps 0.001000.
# running time 0.112928
# ------------------------------
#
# ------------------------------
# Timestep 3472767.
# mean reward (over 100 episodes) 234.490000.
# best mean reward (ever) 552.030000.
# episode # 2335.
# exploration eps 0.001000.
# running time 0.110568
# ------------------------------
#
# ------------------------------
# Timestep 3473870.
# mean reward (over 100 episodes) 234.530000.
# best mean reward (ever) 552.030000.
# episode # 2336.
# exploration eps 0.001000.
# running time 0.110798
# ------------------------------
#
# ------------------------------
# Timestep 3474978.
# mean reward (over 100 episodes) 234.600000.
# best mean reward (ever) 552.030000.
# episode # 2337.
# exploration eps 0.001000.
# running time 0.111231
# ------------------------------
#
# ------------------------------
# Timestep 3477472.
# mean reward (over 100 episodes) 238.220000.
# best mean reward (ever) 552.030000.
# episode # 2338.
# exploration eps 0.001000.
# running time 0.250677
# ------------------------------
#
# ------------------------------
# Timestep 3479692.
# mean reward (over 100 episodes) 241.220000.
# best mean reward (ever) 552.030000.
# episode # 2339.
# exploration eps 0.001000.
# running time 0.222950
# ------------------------------
#
# ------------------------------
# Timestep 3481905.
# mean reward (over 100 episodes) 244.150000.
# best mean reward (ever) 552.030000.
# episode # 2340.
# exploration eps 0.001000.
# running time 0.224019
# ------------------------------
#
# ------------------------------
# Timestep 3482999.
# mean reward (over 100 episodes) 241.300000.
# best mean reward (ever) 552.030000.
# episode # 2341.
# exploration eps 0.001000.
# running time 0.110908
# ------------------------------
#
# ------------------------------
# Timestep 3484099.
# mean reward (over 100 episodes) 241.300000.
# best mean reward (ever) 552.030000.
# episode # 2342.
# exploration eps 0.001000.
# running time 0.111698
# ------------------------------
#
# ------------------------------
# Timestep 3486304.
# mean reward (over 100 episodes) 240.500000.
# best mean reward (ever) 552.030000.
# episode # 2343.
# exploration eps 0.001000.
# running time 0.226704
# ------------------------------
#
# ------------------------------
# Timestep 3487402.
# mean reward (over 100 episodes) 240.510000.
# best mean reward (ever) 552.030000.
# episode # 2344.
# exploration eps 0.001000.
# running time 0.110051
# ------------------------------
#
# ------------------------------
# Timestep 3489612.
# mean reward (over 100 episodes) 243.530000.
# best mean reward (ever) 552.030000.
# episode # 2345.
# exploration eps 0.001000.
# running time 0.222872
# ------------------------------
#
# ------------------------------
# Timestep 3490714.
# mean reward (over 100 episodes) 240.520000.
# best mean reward (ever) 552.030000.
# episode # 2346.
# exploration eps 0.001000.
# running time 0.110869
# ------------------------------
#
# ------------------------------
# Timestep 3491815.
# mean reward (over 100 episodes) 237.490000.
# best mean reward (ever) 552.030000.
# episode # 2347.
# exploration eps 0.001000.
# running time 0.111870
# ------------------------------
#
# ------------------------------
# Timestep 3492924.
# mean reward (over 100 episodes) 237.460000.
# best mean reward (ever) 552.030000.
# episode # 2348.
# exploration eps 0.001000.
# running time 0.111274
# ------------------------------
#
# ------------------------------
# Timestep 3494028.
# mean reward (over 100 episodes) 237.440000.
# best mean reward (ever) 552.030000.
# episode # 2349.
# exploration eps 0.001000.
# running time 0.111220
# ------------------------------
#
# ------------------------------
# Timestep 3495132.
# mean reward (over 100 episodes) 234.670000.
# best mean reward (ever) 552.030000.
# episode # 2350.
# exploration eps 0.001000.
# running time 0.111564
# ------------------------------
#
# ------------------------------
# Timestep 3496238.
# mean reward (over 100 episodes) 234.700000.
# best mean reward (ever) 552.030000.
# episode # 2351.
# exploration eps 0.001000.
# running time 0.112298
# ------------------------------
#
# ------------------------------
# Timestep 3497341.
# mean reward (over 100 episodes) 231.750000.
# best mean reward (ever) 552.030000.
# episode # 2352.
# exploration eps 0.001000.
# running time 0.112845
# ------------------------------
#
# ------------------------------
# Timestep 3499570.
# mean reward (over 100 episodes) 234.660000.
# best mean reward (ever) 552.030000.
# episode # 2353.
# exploration eps 0.001000.
# running time 0.224046
# ------------------------------
#
# ------------------------------
# Timestep 3500668.
# mean reward (over 100 episodes) 234.660000.
# best mean reward (ever) 552.030000.
# episode # 2354.
# exploration eps 0.001000.
# running time 0.113600
# ------------------------------
#
# ------------------------------
# Timestep 3501774.
# mean reward (over 100 episodes) 234.660000.
# best mean reward (ever) 552.030000.
# episode # 2355.
# exploration eps 0.001000.
# running time 0.113261
# ------------------------------
#
# ------------------------------
# Timestep 3502876.
# mean reward (over 100 episodes) 231.890000.
# best mean reward (ever) 552.030000.
# episode # 2356.
# exploration eps 0.001000.
# running time 0.112476
# ------------------------------
#
# ------------------------------
# Timestep 3505094.
# mean reward (over 100 episodes) 234.890000.
# best mean reward (ever) 552.030000.
# episode # 2357.
# exploration eps 0.001000.
# running time 0.223681
# ------------------------------
#
# ------------------------------
# Timestep 3506203.
# mean reward (over 100 episodes) 231.900000.
# best mean reward (ever) 552.030000.
# episode # 2358.
# exploration eps 0.001000.
# running time 0.111425
# ------------------------------
#
# ------------------------------
# Timestep 3507315.
# mean reward (over 100 episodes) 231.930000.
# best mean reward (ever) 552.030000.
# episode # 2359.
# exploration eps 0.001000.
# running time 0.112480
# ------------------------------
#
# ------------------------------
# Timestep 3508422.
# mean reward (over 100 episodes) 231.930000.
# best mean reward (ever) 552.030000.
# episode # 2360.
# exploration eps 0.001000.
# running time 0.111805
# ------------------------------
#
# ------------------------------
# Timestep 3509531.
# mean reward (over 100 episodes) 231.950000.
# best mean reward (ever) 552.030000.
# episode # 2361.
# exploration eps 0.001000.
# running time 0.112638
# ------------------------------
#
# ------------------------------
# Timestep 3510636.
# mean reward (over 100 episodes) 232.020000.
# best mean reward (ever) 552.030000.
# episode # 2362.
# exploration eps 0.001000.
# running time 0.113252
# ------------------------------
#
# ------------------------------
# Timestep 3511740.
# mean reward (over 100 episodes) 229.010000.
# best mean reward (ever) 552.030000.
# episode # 2363.
# exploration eps 0.001000.
# running time 0.112483
# ------------------------------
#
# ------------------------------
# Timestep 3512841.
# mean reward (over 100 episodes) 228.980000.
# best mean reward (ever) 552.030000.
# episode # 2364.
# exploration eps 0.001000.
# running time 0.111719
# ------------------------------
#
# ------------------------------
# Timestep 3513944.
# mean reward (over 100 episodes) 229.040000.
# best mean reward (ever) 552.030000.
# episode # 2365.
# exploration eps 0.001000.
# running time 0.110561
# ------------------------------
#
# ------------------------------
# Timestep 3515047.
# mean reward (over 100 episodes) 229.030000.
# best mean reward (ever) 552.030000.
# episode # 2366.
# exploration eps 0.001000.
# running time 0.110464
# ------------------------------
#
# ------------------------------
# Timestep 3516147.
# mean reward (over 100 episodes) 229.050000.
# best mean reward (ever) 552.030000.
# episode # 2367.
# exploration eps 0.001000.
# running time 0.110647
# ------------------------------
#
# ------------------------------
# Timestep 3517250.
# mean reward (over 100 episodes) 229.040000.
# best mean reward (ever) 552.030000.
# episode # 2368.
# exploration eps 0.001000.
# running time 0.111083
# ------------------------------
#
# ------------------------------
# Timestep 3518351.
# mean reward (over 100 episodes) 229.080000.
# best mean reward (ever) 552.030000.
# episode # 2369.
# exploration eps 0.001000.
# running time 0.111058
# ------------------------------
#
# ------------------------------
# Timestep 3519450.
# mean reward (over 100 episodes) 229.050000.
# best mean reward (ever) 552.030000.
# episode # 2370.
# exploration eps 0.001000.
# running time 0.111261
# ------------------------------
#
# ------------------------------
# Timestep 3520559.
# mean reward (over 100 episodes) 229.110000.
# best mean reward (ever) 552.030000.
# episode # 2371.
# exploration eps 0.001000.
# running time 0.111049
# ------------------------------
#
# ------------------------------
# Timestep 3521666.
# mean reward (over 100 episodes) 229.100000.
# best mean reward (ever) 552.030000.
# episode # 2372.
# exploration eps 0.001000.
# running time 0.111950
# ------------------------------
#
# ------------------------------
# Timestep 3523882.
# mean reward (over 100 episodes) 232.140000.
# best mean reward (ever) 552.030000.
# episode # 2373.
# exploration eps 0.001000.
# running time 0.222736
# ------------------------------
#
# ------------------------------
# Timestep 3524978.
# mean reward (over 100 episodes) 232.140000.
# best mean reward (ever) 552.030000.
# episode # 2374.
# exploration eps 0.001000.
# running time 0.110263
# ------------------------------
#
# ------------------------------
# Timestep 3527190.
# mean reward (over 100 episodes) 235.120000.
# best mean reward (ever) 552.030000.
# episode # 2375.
# exploration eps 0.001000.
# running time 0.223240
# ------------------------------
#
# ------------------------------
# Timestep 3528296.
# mean reward (over 100 episodes) 235.070000.
# best mean reward (ever) 552.030000.
# episode # 2376.
# exploration eps 0.001000.
# running time 0.111170
# ------------------------------
#
# ------------------------------
# Timestep 3529400.
# mean reward (over 100 episodes) 235.060000.
# best mean reward (ever) 552.030000.
# episode # 2377.
# exploration eps 0.001000.
# running time 0.110956
# ------------------------------
#
# ------------------------------
# Timestep 3530506.
# mean reward (over 100 episodes) 235.050000.
# best mean reward (ever) 552.030000.
# episode # 2378.
# exploration eps 0.001000.
# running time 0.111047
# ------------------------------
#
# ------------------------------
# Timestep 3531603.
# mean reward (over 100 episodes) 235.020000.
# best mean reward (ever) 552.030000.
# episode # 2379.
# exploration eps 0.001000.
# running time 0.111653
# ------------------------------
#
# ------------------------------
# Timestep 3532714.
# mean reward (over 100 episodes) 235.050000.
# best mean reward (ever) 552.030000.
# episode # 2380.
# exploration eps 0.001000.
# running time 0.110793
# ------------------------------
#
# ------------------------------
# Timestep 3533823.
# mean reward (over 100 episodes) 235.120000.
# best mean reward (ever) 552.030000.
# episode # 2381.
# exploration eps 0.001000.
# running time 0.110640
# ------------------------------
#
# ------------------------------
# Timestep 3536029.
# mean reward (over 100 episodes) 237.400000.
# best mean reward (ever) 552.030000.
# episode # 2382.
# exploration eps 0.001000.
# running time 0.226178
# ------------------------------
#
# ------------------------------
# Timestep 3538230.
# mean reward (over 100 episodes) 240.350000.
# best mean reward (ever) 552.030000.
# episode # 2383.
# exploration eps 0.001000.
# running time 0.224628
# ------------------------------
#
# ------------------------------
# Timestep 3540442.
# mean reward (over 100 episodes) 240.600000.
# best mean reward (ever) 552.030000.
# episode # 2384.
# exploration eps 0.001000.
# running time 0.222825
# ------------------------------
#
# ------------------------------
# Timestep 3541551.
# mean reward (over 100 episodes) 240.630000.
# best mean reward (ever) 552.030000.
# episode # 2385.
# exploration eps 0.001000.
# running time 0.112439
# ------------------------------
#
# ------------------------------
# Timestep 3542659.
# mean reward (over 100 episodes) 240.650000.
# best mean reward (ever) 552.030000.
# episode # 2386.
# exploration eps 0.001000.
# running time 0.111289
# ------------------------------
#
# ------------------------------
# Timestep 3543758.
# mean reward (over 100 episodes) 240.700000.
# best mean reward (ever) 552.030000.
# episode # 2387.
# exploration eps 0.001000.
# running time 0.110524
# ------------------------------
#
# ------------------------------
# Timestep 3545984.
# mean reward (over 100 episodes) 243.720000.
# best mean reward (ever) 552.030000.
# episode # 2388.
# exploration eps 0.001000.
# running time 0.223453
# ------------------------------
#
# ------------------------------
# Timestep 3547090.
# mean reward (over 100 episodes) 243.720000.
# best mean reward (ever) 552.030000.
# episode # 2389.
# exploration eps 0.001000.
# running time 0.110892
# ------------------------------
#
# ------------------------------
# Timestep 3549301.
# mean reward (over 100 episodes) 246.300000.
# best mean reward (ever) 552.030000.
# episode # 2390.
# exploration eps 0.001000.
# running time 0.222038
# ------------------------------
#
# ------------------------------
# Timestep 3551513.
# mean reward (over 100 episodes) 249.310000.
# best mean reward (ever) 552.030000.
# episode # 2391.
# exploration eps 0.001000.
# running time 0.223504
# ------------------------------
#
# ------------------------------
# Timestep 3553723.
# mean reward (over 100 episodes) 251.880000.
# best mean reward (ever) 552.030000.
# episode # 2392.
# exploration eps 0.001000.
# running time 0.222324
# ------------------------------
#
# ------------------------------
# Timestep 3554833.
# mean reward (over 100 episodes) 251.870000.
# best mean reward (ever) 552.030000.
# episode # 2393.
# exploration eps 0.001000.
# running time 0.111648
# ------------------------------
#
# ------------------------------
# Timestep 3557031.
# mean reward (over 100 episodes) 254.810000.
# best mean reward (ever) 552.030000.
# episode # 2394.
# exploration eps 0.001000.
# running time 0.222643
# ------------------------------
#
# ------------------------------
# Timestep 3559239.
# mean reward (over 100 episodes) 257.850000.
# best mean reward (ever) 552.030000.
# episode # 2395.
# exploration eps 0.001000.
# running time 0.221194
# ------------------------------
#
# ------------------------------
# Timestep 3560340.
# mean reward (over 100 episodes) 257.860000.
# best mean reward (ever) 552.030000.
# episode # 2396.
# exploration eps 0.001000.
# running time 0.111861
# ------------------------------
#
# ------------------------------
# Timestep 3562551.
# mean reward (over 100 episodes) 260.910000.
# best mean reward (ever) 552.030000.
# episode # 2397.
# exploration eps 0.001000.
# running time 0.225252
# ------------------------------
#
# ------------------------------
# Timestep 3563654.
# mean reward (over 100 episodes) 260.900000.
# best mean reward (ever) 552.030000.
# episode # 2398.
# exploration eps 0.001000.
# running time 0.111193
# ------------------------------
#
# ------------------------------
# Timestep 3564762.
# mean reward (over 100 episodes) 260.880000.
# best mean reward (ever) 552.030000.
# episode # 2399.
# exploration eps 0.001000.
# running time 0.111776
# ------------------------------
#
# ------------------------------
# Timestep 3566972.
# mean reward (over 100 episodes) 263.920000.
# best mean reward (ever) 552.030000.
# episode # 2400.
# exploration eps 0.001000.
# running time 0.223221
# ------------------------------
#
# ------------------------------
# Timestep 3568079.
# mean reward (over 100 episodes) 263.930000.
# best mean reward (ever) 552.030000.
# episode # 2401.
# exploration eps 0.001000.
# running time 0.111461
# ------------------------------
#
# ------------------------------
# Timestep 3570283.
# mean reward (over 100 episodes) 266.930000.
# best mean reward (ever) 552.030000.
# episode # 2402.
# exploration eps 0.001000.
# running time 0.222034
# ------------------------------
#
# ------------------------------
# Timestep 3571377.
# mean reward (over 100 episodes) 266.920000.
# best mean reward (ever) 552.030000.
# episode # 2403.
# exploration eps 0.001000.
# running time 0.111479
# ------------------------------
#
# ------------------------------
# Timestep 3572487.
# mean reward (over 100 episodes) 266.910000.
# best mean reward (ever) 552.030000.
# episode # 2404.
# exploration eps 0.001000.
# running time 0.111413
# ------------------------------
#
# ------------------------------
# Timestep 3573591.
# mean reward (over 100 episodes) 266.920000.
# best mean reward (ever) 552.030000.
# episode # 2405.
# exploration eps 0.001000.
# running time 0.111766
# ------------------------------
#
# ------------------------------
# Timestep 3575803.
# mean reward (over 100 episodes) 269.930000.
# best mean reward (ever) 552.030000.
# episode # 2406.
# exploration eps 0.001000.
# running time 0.222059
# ------------------------------
#
# ------------------------------
# Timestep 3576911.
# mean reward (over 100 episodes) 269.920000.
# best mean reward (ever) 552.030000.
# episode # 2407.
# exploration eps 0.001000.
# running time 0.112360
# ------------------------------
#
# ------------------------------
# Timestep 3578007.
# mean reward (over 100 episodes) 269.930000.
# best mean reward (ever) 552.030000.
# episode # 2408.
# exploration eps 0.001000.
# running time 0.111133
# ------------------------------
#
# ------------------------------
# Timestep 3579106.
# mean reward (over 100 episodes) 269.940000.
# best mean reward (ever) 552.030000.
# episode # 2409.
# exploration eps 0.001000.
# running time 0.110382
# ------------------------------
#
# ------------------------------
# Timestep 3580207.
# mean reward (over 100 episodes) 269.940000.
# best mean reward (ever) 552.030000.
# episode # 2410.
# exploration eps 0.001000.
# running time 0.110409
# ------------------------------
#
# ------------------------------
# Timestep 3581303.
# mean reward (over 100 episodes) 269.930000.
# best mean reward (ever) 552.030000.
# episode # 2411.
# exploration eps 0.001000.
# running time 0.110585
# ------------------------------
#
# ------------------------------
# Timestep 3582406.
# mean reward (over 100 episodes) 267.070000.
# best mean reward (ever) 552.030000.
# episode # 2412.
# exploration eps 0.001000.
# running time 0.110799
# ------------------------------
#
# ------------------------------
# Timestep 3583513.
# mean reward (over 100 episodes) 267.070000.
# best mean reward (ever) 552.030000.
# episode # 2413.
# exploration eps 0.001000.
# running time 0.111114
# ------------------------------
#
# ------------------------------
# Timestep 3584615.
# mean reward (over 100 episodes) 267.050000.
# best mean reward (ever) 552.030000.
# episode # 2414.
# exploration eps 0.001000.
# running time 0.110947
# ------------------------------
#
# ------------------------------
# Timestep 3585727.
# mean reward (over 100 episodes) 267.050000.
# best mean reward (ever) 552.030000.
# episode # 2415.
# exploration eps 0.001000.
# running time 0.112044
# ------------------------------
#
# ------------------------------
# Timestep 3586828.
# mean reward (over 100 episodes) 264.360000.
# best mean reward (ever) 552.030000.
# episode # 2416.
# exploration eps 0.001000.
# running time 0.111840
# ------------------------------
#
# ------------------------------
# Timestep 3587932.
# mean reward (over 100 episodes) 264.360000.
# best mean reward (ever) 552.030000.
# episode # 2417.
# exploration eps 0.001000.
# running time 0.114450
# ------------------------------
#
# ------------------------------
# Timestep 3589030.
# mean reward (over 100 episodes) 264.330000.
# best mean reward (ever) 552.030000.
# episode # 2418.
# exploration eps 0.001000.
# running time 0.111815
# ------------------------------
#
# ------------------------------
# Timestep 3590132.
# mean reward (over 100 episodes) 264.330000.
# best mean reward (ever) 552.030000.
# episode # 2419.
# exploration eps 0.001000.
# running time 0.111442
# ------------------------------
#
# ------------------------------
# Timestep 3591248.
# mean reward (over 100 episodes) 264.370000.
# best mean reward (ever) 552.030000.
# episode # 2420.
# exploration eps 0.001000.
# running time 0.112697
# ------------------------------
#
# ------------------------------
# Timestep 3592344.
# mean reward (over 100 episodes) 261.390000.
# best mean reward (ever) 552.030000.
# episode # 2421.
# exploration eps 0.001000.
# running time 0.110661
# ------------------------------
#
# ------------------------------
# Timestep 3593454.
# mean reward (over 100 episodes) 261.390000.
# best mean reward (ever) 552.030000.
# episode # 2422.
# exploration eps 0.001000.
# running time 0.110757
# ------------------------------
#
# ------------------------------
# Timestep 3594560.
# mean reward (over 100 episodes) 261.410000.
# best mean reward (ever) 552.030000.
# episode # 2423.
# exploration eps 0.001000.
# running time 0.111715
# ------------------------------
#
# ------------------------------
# Timestep 3595673.
# mean reward (over 100 episodes) 261.400000.
# best mean reward (ever) 552.030000.
# episode # 2424.
# exploration eps 0.001000.
# running time 0.111660
# ------------------------------
#
# ------------------------------
# Timestep 3596772.
# mean reward (over 100 episodes) 261.420000.
# best mean reward (ever) 552.030000.
# episode # 2425.
# exploration eps 0.001000.
# running time 0.111474
# ------------------------------
#
# ------------------------------
# Timestep 3597868.
# mean reward (over 100 episodes) 261.410000.
# best mean reward (ever) 552.030000.
# episode # 2426.
# exploration eps 0.001000.
# running time 0.110774
# ------------------------------
#
# ------------------------------
# Timestep 3598979.
# mean reward (over 100 episodes) 261.400000.
# best mean reward (ever) 552.030000.
# episode # 2427.
# exploration eps 0.001000.
# running time 0.111276
# ------------------------------
#
# ------------------------------
# Timestep 3601190.
# mean reward (over 100 episodes) 264.260000.
# best mean reward (ever) 552.030000.
# episode # 2428.
# exploration eps 0.001000.
# running time 0.221804
# ------------------------------
#
# ------------------------------
# Timestep 3602292.
# mean reward (over 100 episodes) 264.200000.
# best mean reward (ever) 552.030000.
# episode # 2429.
# exploration eps 0.001000.
# running time 0.111273
# ------------------------------
#
# ------------------------------
# Timestep 3603397.
# mean reward (over 100 episodes) 264.220000.
# best mean reward (ever) 552.030000.
# episode # 2430.
# exploration eps 0.001000.
# running time 0.111784
# ------------------------------
#
# ------------------------------
# Timestep 3604513.
# mean reward (over 100 episodes) 264.200000.
# best mean reward (ever) 552.030000.
# episode # 2431.
# exploration eps 0.001000.
# running time 0.112615
# ------------------------------
#
# ------------------------------
# Timestep 3605619.
# mean reward (over 100 episodes) 264.170000.
# best mean reward (ever) 552.030000.
# episode # 2432.
# exploration eps 0.001000.
# running time 0.111231
# ------------------------------
#
# ------------------------------
# Timestep 3606723.
# mean reward (over 100 episodes) 264.160000.
# best mean reward (ever) 552.030000.
# episode # 2433.
# exploration eps 0.001000.
# running time 0.111840
# ------------------------------
#
# ------------------------------
# Timestep 3607829.
# mean reward (over 100 episodes) 264.180000.
# best mean reward (ever) 552.030000.
# episode # 2434.
# exploration eps 0.001000.
# running time 0.111988
# ------------------------------
#
# ------------------------------
# Timestep 3608930.
# mean reward (over 100 episodes) 264.190000.
# best mean reward (ever) 552.030000.
# episode # 2435.
# exploration eps 0.001000.
# running time 0.110425
# ------------------------------
#
# ------------------------------
# Timestep 3610030.
# mean reward (over 100 episodes) 264.200000.
# best mean reward (ever) 552.030000.
# episode # 2436.
# exploration eps 0.001000.
# running time 0.110638
# ------------------------------
#
# ------------------------------
# Timestep 3611137.
# mean reward (over 100 episodes) 264.210000.
# best mean reward (ever) 552.030000.
# episode # 2437.
# exploration eps 0.001000.
# running time 0.113002
# ------------------------------
#
# ------------------------------
# Timestep 3612250.
# mean reward (over 100 episodes) 260.590000.
# best mean reward (ever) 552.030000.
# episode # 2438.
# exploration eps 0.001000.
# running time 0.112616
# ------------------------------
#
# ------------------------------
# Timestep 3613364.
# mean reward (over 100 episodes) 257.600000.
# best mean reward (ever) 552.030000.
# episode # 2439.
# exploration eps 0.001000.
# running time 0.112834
# ------------------------------
#
# ------------------------------
# Timestep 3614465.
# mean reward (over 100 episodes) 254.560000.
# best mean reward (ever) 552.030000.
# episode # 2440.
# exploration eps 0.001000.
# running time 0.111161
# ------------------------------
#
# ------------------------------
# Timestep 3615573.
# mean reward (over 100 episodes) 254.560000.
# best mean reward (ever) 552.030000.
# episode # 2441.
# exploration eps 0.001000.
# running time 0.111742
# ------------------------------
#
# ------------------------------
# Timestep 3616675.
# mean reward (over 100 episodes) 254.540000.
# best mean reward (ever) 552.030000.
# episode # 2442.
# exploration eps 0.001000.
# running time 0.112308
# ------------------------------
#
# ------------------------------
# Timestep 3617773.
# mean reward (over 100 episodes) 251.610000.
# best mean reward (ever) 552.030000.
# episode # 2443.
# exploration eps 0.001000.
# running time 0.111396
# ------------------------------
#
# ------------------------------
# Timestep 3618877.
# mean reward (over 100 episodes) 251.560000.
# best mean reward (ever) 552.030000.
# episode # 2444.
# exploration eps 0.001000.
# running time 0.111381
# ------------------------------
#
# ------------------------------
# Timestep 3619972.
# mean reward (over 100 episodes) 248.550000.
# best mean reward (ever) 552.030000.
# episode # 2445.
# exploration eps 0.001000.
# running time 0.110179
# ------------------------------
#
# ------------------------------
# Timestep 3621069.
# mean reward (over 100 episodes) 248.540000.
# best mean reward (ever) 552.030000.
# episode # 2446.
# exploration eps 0.001000.
# running time 0.110605
# ------------------------------
#
# ------------------------------
# Timestep 3622171.
# mean reward (over 100 episodes) 248.590000.
# best mean reward (ever) 552.030000.
# episode # 2447.
# exploration eps 0.001000.
# running time 0.110528
# ------------------------------
#
# ------------------------------
# Timestep 3623272.
# mean reward (over 100 episodes) 248.600000.
# best mean reward (ever) 552.030000.
# episode # 2448.
# exploration eps 0.001000.
# running time 0.111022
# ------------------------------
#
# ------------------------------
# Timestep 3624381.
# mean reward (over 100 episodes) 248.580000.
# best mean reward (ever) 552.030000.
# episode # 2449.
# exploration eps 0.001000.
# running time 0.110999
# ------------------------------
#
# ------------------------------
# Timestep 3625484.
# mean reward (over 100 episodes) 248.580000.
# best mean reward (ever) 552.030000.
# episode # 2450.
# exploration eps 0.001000.
# running time 0.110880
# ------------------------------
#
# ------------------------------
# Timestep 3626584.
# mean reward (over 100 episodes) 248.580000.
# best mean reward (ever) 552.030000.
# episode # 2451.
# exploration eps 0.001000.
# running time 0.111321
# ------------------------------
#
# ------------------------------
# Timestep 3628802.
# mean reward (over 100 episodes) 251.550000.
# best mean reward (ever) 552.030000.
# episode # 2452.
# exploration eps 0.001000.
# running time 0.223953
# ------------------------------
#
# ------------------------------
# Timestep 3629906.
# mean reward (over 100 episodes) 248.620000.
# best mean reward (ever) 552.030000.
# episode # 2453.
# exploration eps 0.001000.
# running time 0.112471
# ------------------------------
#
# ------------------------------
# Timestep 3631004.
# mean reward (over 100 episodes) 248.600000.
# best mean reward (ever) 552.030000.
# episode # 2454.
# exploration eps 0.001000.
# running time 0.111502
# ------------------------------
#
# ------------------------------
# Timestep 3632106.
# mean reward (over 100 episodes) 248.600000.
# best mean reward (ever) 552.030000.
# episode # 2455.
# exploration eps 0.001000.
# running time 0.110290
# ------------------------------
#
# ------------------------------
# Timestep 3633205.
# mean reward (over 100 episodes) 248.610000.
# best mean reward (ever) 552.030000.
# episode # 2456.
# exploration eps 0.001000.
# running time 0.111395
# ------------------------------
#
# ------------------------------
# Timestep 3634310.
# mean reward (over 100 episodes) 245.600000.
# best mean reward (ever) 552.030000.
# episode # 2457.
# exploration eps 0.001000.
# running time 0.111877
# ------------------------------
#
# ------------------------------
# Timestep 3635404.
# mean reward (over 100 episodes) 245.570000.
# best mean reward (ever) 552.030000.
# episode # 2458.
# exploration eps 0.001000.
# running time 0.110547
# ------------------------------
#
# ------------------------------
# Timestep 3636508.
# mean reward (over 100 episodes) 245.570000.
# best mean reward (ever) 552.030000.
# episode # 2459.
# exploration eps 0.001000.
# running time 0.110870
# ------------------------------
#
# ------------------------------
# Timestep 3637612.
# mean reward (over 100 episodes) 245.570000.
# best mean reward (ever) 552.030000.
# episode # 2460.
# exploration eps 0.001000.
# running time 0.111309
# ------------------------------
#
# ------------------------------
# Timestep 3638717.
# mean reward (over 100 episodes) 245.550000.
# best mean reward (ever) 552.030000.
# episode # 2461.
# exploration eps 0.001000.
# running time 0.114264
# ------------------------------
#
# ------------------------------
# Timestep 3639817.
# mean reward (over 100 episodes) 245.530000.
# best mean reward (ever) 552.030000.
# episode # 2462.
# exploration eps 0.001000.
# running time 0.113287
# ------------------------------
#
# ------------------------------
# Timestep 3640931.
# mean reward (over 100 episodes) 245.520000.
# best mean reward (ever) 552.030000.
# episode # 2463.
# exploration eps 0.001000.
# running time 0.112682
# ------------------------------
#
# ------------------------------
# Timestep 3642026.
# mean reward (over 100 episodes) 245.550000.
# best mean reward (ever) 552.030000.
# episode # 2464.
# exploration eps 0.001000.
# running time 0.111199
# ------------------------------
#
# ------------------------------
# Timestep 3643129.
# mean reward (over 100 episodes) 245.500000.
# best mean reward (ever) 552.030000.
# episode # 2465.
# exploration eps 0.001000.
# running time 0.111951
# ------------------------------
#
# ------------------------------
# Timestep 3644226.
# mean reward (over 100 episodes) 245.510000.
# best mean reward (ever) 552.030000.
# episode # 2466.
# exploration eps 0.001000.
# running time 0.111249
# ------------------------------
#
# ------------------------------
# Timestep 3645326.
# mean reward (over 100 episodes) 245.540000.
# best mean reward (ever) 552.030000.
# episode # 2467.
# exploration eps 0.001000.
# running time 0.110776
# ------------------------------
#
# ------------------------------
# Timestep 3646431.
# mean reward (over 100 episodes) 245.550000.
# best mean reward (ever) 552.030000.
# episode # 2468.
# exploration eps 0.001000.
# running time 0.111112
# ------------------------------
#
# ------------------------------
# Timestep 3647531.
# mean reward (over 100 episodes) 245.520000.
# best mean reward (ever) 552.030000.
# episode # 2469.
# exploration eps 0.001000.
# running time 0.110542
# ------------------------------
#
# ------------------------------
# Timestep 3648639.
# mean reward (over 100 episodes) 245.530000.
# best mean reward (ever) 552.030000.
# episode # 2470.
# exploration eps 0.001000.
# running time 0.111798
# ------------------------------
#
# ------------------------------
# Timestep 3649751.
# mean reward (over 100 episodes) 245.530000.
# best mean reward (ever) 552.030000.
# episode # 2471.
# exploration eps 0.001000.
# running time 0.112372
# ------------------------------
#
# ------------------------------
# Timestep 3650861.
# mean reward (over 100 episodes) 245.530000.
# best mean reward (ever) 552.030000.
# episode # 2472.
# exploration eps 0.001000.
# running time 0.113068
# ------------------------------
#
# ------------------------------
# Timestep 3651965.
# mean reward (over 100 episodes) 242.550000.
# best mean reward (ever) 552.030000.
# episode # 2473.
# exploration eps 0.001000.
# running time 0.110859
# ------------------------------
#
# ------------------------------
# Timestep 3653074.
# mean reward (over 100 episodes) 242.530000.
# best mean reward (ever) 552.030000.
# episode # 2474.
# exploration eps 0.001000.
# running time 0.111795
# ------------------------------
#
# ------------------------------
# Timestep 3654176.
# mean reward (over 100 episodes) 239.520000.
# best mean reward (ever) 552.030000.
# episode # 2475.
# exploration eps 0.001000.
# running time 0.110900
# ------------------------------
#
# ------------------------------
# Timestep 3655280.
# mean reward (over 100 episodes) 239.530000.
# best mean reward (ever) 552.030000.
# episode # 2476.
# exploration eps 0.001000.
# running time 0.111433
# ------------------------------
#
# ------------------------------
# Timestep 3656382.
# mean reward (over 100 episodes) 239.510000.
# best mean reward (ever) 552.030000.
# episode # 2477.
# exploration eps 0.001000.
# running time 0.111786
# ------------------------------
#
# ------------------------------
# Timestep 3657492.
# mean reward (over 100 episodes) 239.510000.
# best mean reward (ever) 552.030000.
# episode # 2478.
# exploration eps 0.001000.
# running time 0.112592
# ------------------------------
#
# ------------------------------
# Timestep 3658601.
# mean reward (over 100 episodes) 239.530000.
# best mean reward (ever) 552.030000.
# episode # 2479.
# exploration eps 0.001000.
# running time 0.111172
# ------------------------------
#
# ------------------------------
# Timestep 3660808.
# mean reward (over 100 episodes) 242.500000.
# best mean reward (ever) 552.030000.
# episode # 2480.
# exploration eps 0.001000.
# running time 0.223637
# ------------------------------
#
# ------------------------------
# Timestep 3661914.
# mean reward (over 100 episodes) 242.470000.
# best mean reward (ever) 552.030000.
# episode # 2481.
# exploration eps 0.001000.
# running time 0.113209
# ------------------------------
#
# ------------------------------
# Timestep 3663022.
# mean reward (over 100 episodes) 240.190000.
# best mean reward (ever) 552.030000.
# episode # 2482.
# exploration eps 0.001000.
# running time 0.111552
# ------------------------------
#
# ------------------------------
# Timestep 3664118.
# mean reward (over 100 episodes) 237.230000.
# best mean reward (ever) 552.030000.
# episode # 2483.
# exploration eps 0.001000.
# running time 0.110615
# ------------------------------
#
# ------------------------------
# Timestep 3665228.
# mean reward (over 100 episodes) 234.210000.
# best mean reward (ever) 552.030000.
# episode # 2484.
# exploration eps 0.001000.
# running time 0.112161
# ------------------------------
#
# ------------------------------
# Timestep 3666329.
# mean reward (over 100 episodes) 234.140000.
# best mean reward (ever) 552.030000.
# episode # 2485.
# exploration eps 0.001000.
# running time 0.111198
# ------------------------------
#
# ------------------------------
# Timestep 3667441.
# mean reward (over 100 episodes) 234.130000.
# best mean reward (ever) 552.030000.
# episode # 2486.
# exploration eps 0.001000.
# running time 0.112415
# ------------------------------
#
# ------------------------------
# Timestep 3668546.
# mean reward (over 100 episodes) 234.110000.
# best mean reward (ever) 552.030000.
# episode # 2487.
# exploration eps 0.001000.
# running time 0.111524
# ------------------------------
#
# ------------------------------
# Timestep 3669649.
# mean reward (over 100 episodes) 231.100000.
# best mean reward (ever) 552.030000.
# episode # 2488.
# exploration eps 0.001000.
# running time 0.113183
# ------------------------------
#
# ------------------------------
# Timestep 3670759.
# mean reward (over 100 episodes) 231.070000.
# ...
#
# ------------------------------
# Timestep 4071101.
# mean reward (over 100 episodes) 304.410000.
# best mean reward (ever) 552.030000.
# episode # 2761.
# exploration eps 0.001000.
# running time 0.111082
# ------------------------------
#
# ------------------------------
# Timestep 4072206.
# mean reward (over 100 episodes) 301.370000.
# best mean reward (ever) 552.030000.
# episode # 2762.
# exploration eps 0.001000.
# running time 0.111211
# ------------------------------
#
# ------------------------------
# Timestep 4073305.
# mean reward (over 100 episodes) 298.310000.
# best mean reward (ever) 552.030000.
# episode # 2763.
# exploration eps 0.001000.
# running time 0.111601
# ------------------------------
#
# ------------------------------
# Timestep 4074408.
# mean reward (over 100 episodes) 298.330000.
# best mean reward (ever) 552.030000.
# episode # 2764.
# exploration eps 0.001000.
# running time 0.110965
# ------------------------------
#
# ------------------------------
# Timestep 4075520.
# mean reward (over 100 episodes) 295.260000.
# best mean reward (ever) 552.030000.
# episode # 2765.
# exploration eps 0.001000.
# running time 0.111482
# ------------------------------
#
# ------------------------------
# Timestep 4076626.
# mean reward (over 100 episodes) 292.220000.
# best mean reward (ever) 552.030000.
# episode # 2766.
# exploration eps 0.001000.
# running time 0.111237
# ------------------------------
#
# ------------------------------
# Timestep 4077728.
# mean reward (over 100 episodes) 288.710000.
# best mean reward (ever) 552.030000.
# episode # 2767.
# exploration eps 0.001000.
# running time 0.112033
# ------------------------------
#
# ------------------------------
# Timestep 4078833.
# mean reward (over 100 episodes) 285.660000.
# best mean reward (ever) 552.030000.
# episode # 2768.
# exploration eps 0.001000.
# running time 0.111695
# ------------------------------
#
# ------------------------------
# Timestep 4079937.
# mean reward (over 100 episodes) 282.610000.
# best mean reward (ever) 552.030000.
# episode # 2769.
# exploration eps 0.001000.
# running time 0.111652
# ------------------------------
#
# ------------------------------
# Timestep 4081044.
# mean reward (over 100 episodes) 279.520000.
# best mean reward (ever) 552.030000.
# episode # 2770.
# exploration eps 0.001000.
# running time 0.110737
# ------------------------------
#
# ------------------------------
# Timestep 4082151.
# mean reward (over 100 episodes) 276.510000.
# best mean reward (ever) 552.030000.
# episode # 2771.
# exploration eps 0.001000.
# running time 0.111819
# ------------------------------
#
# ------------------------------
# Timestep 4083246.
# mean reward (over 100 episodes) 276.480000.
# best mean reward (ever) 552.030000.
# episode # 2772.
# exploration eps 0.001000.
# running time 0.110590
# ------------------------------
#
# ------------------------------
# Timestep 4084361.
# mean reward (over 100 episodes) 273.530000.
# best mean reward (ever) 552.030000.
# episode # 2773.
# exploration eps 0.001000.
# running time 0.112279
# ------------------------------
#
# ------------------------------
# Timestep 4085469.
# mean reward (over 100 episodes) 270.380000.
# best mean reward (ever) 552.030000.
# episode # 2774.
# exploration eps 0.001000.
# running time 0.111242
# ------------------------------
#
# ------------------------------
# Timestep 4086577.
# mean reward (over 100 episodes) 267.350000.
# best mean reward (ever) 552.030000.
# episode # 2775.
# exploration eps 0.001000.
# running time 0.111709
# ------------------------------
#
# ------------------------------
# Timestep 4087675.
# mean reward (over 100 episodes) 264.260000.
# best mean reward (ever) 552.030000.
# episode # 2776.
# exploration eps 0.001000.
# running time 0.110638
# ------------------------------
#
# ------------------------------
# Timestep 4088780.
# mean reward (over 100 episodes) 261.290000.
# best mean reward (ever) 552.030000.
# episode # 2777.
# exploration eps 0.001000.
# running time 0.111696
# ------------------------------
#
# ------------------------------
# Timestep 4089885.
# mean reward (over 100 episodes) 258.240000.
# best mean reward (ever) 552.030000.
# episode # 2778.
# exploration eps 0.001000.
# running time 0.111719
# ------------------------------
#
# ------------------------------
# Timestep 4090988.
# mean reward (over 100 episodes) 258.180000.
# best mean reward (ever) 552.030000.
# episode # 2779.
# exploration eps 0.001000.
# running time 0.111023
# ------------------------------
#
# ------------------------------
# Timestep 4092086.
# mean reward (over 100 episodes) 255.120000.
# best mean reward (ever) 552.030000.
# episode # 2780.
# exploration eps 0.001000.
# running time 0.111854
# ------------------------------
#
# ------------------------------
# Timestep 4093187.
# mean reward (over 100 episodes) 255.070000.
# best mean reward (ever) 552.030000.
# episode # 2781.
# exploration eps 0.001000.
# running time 0.110863
# ------------------------------
#
# ------------------------------
# Timestep 4094293.
# mean reward (over 100 episodes) 252.000000.
# best mean reward (ever) 552.030000.
# episode # 2782.
# exploration eps 0.001000.
# running time 0.111509
# ------------------------------
#
# ------------------------------
# Timestep 4095398.
# mean reward (over 100 episodes) 249.210000.
# best mean reward (ever) 552.030000.
# episode # 2783.
# exploration eps 0.001000.
# running time 0.110622
# ------------------------------
#
# ------------------------------
# Timestep 4096497.
# mean reward (over 100 episodes) 249.070000.
# best mean reward (ever) 552.030000.
# episode # 2784.
# exploration eps 0.001000.
# running time 0.110848
# ------------------------------
#
# ------------------------------
# Timestep 4097606.
# mean reward (over 100 episodes) 249.030000.
# best mean reward (ever) 552.030000.
# episode # 2785.
# exploration eps 0.001000.
# running time 0.113715
# ------------------------------
#
# ------------------------------
# Timestep 4098714.
# mean reward (over 100 episodes) 246.060000.
# best mean reward (ever) 552.030000.
# episode # 2786.
# exploration eps 0.001000.
# running time 0.113272
# ------------------------------
#
# ------------------------------
# Timestep 4099814.
# mean reward (over 100 episodes) 243.030000.
# best mean reward (ever) 552.030000.
# episode # 2787.
# exploration eps 0.001000.
# running time 0.111147
# ------------------------------
#
# ------------------------------
# Timestep 4100914.
# mean reward (over 100 episodes) 242.980000.
# best mean reward (ever) 552.030000.
# episode # 2788.
# exploration eps 0.001000.
# running time 0.110744
# ------------------------------
#
# ------------------------------
# Timestep 4102013.
# mean reward (over 100 episodes) 242.950000.
# best mean reward (ever) 552.030000.
# episode # 2789.
# exploration eps 0.001000.
# running time 0.110673
# ------------------------------
#
# ------------------------------
# Timestep 4103120.
# mean reward (over 100 episodes) 242.890000.
# best mean reward (ever) 552.030000.
# episode # 2790.
# exploration eps 0.001000.
# running time 0.110794
# ------------------------------
#
# ------------------------------
# Timestep 4104228.
# mean reward (over 100 episodes) 239.820000.
# best mean reward (ever) 552.030000.
# episode # 2791.
# exploration eps 0.001000.
# running time 0.111461
# ------------------------------
#
# ------------------------------
# Timestep 4105335.
# mean reward (over 100 episodes) 236.740000.
# best mean reward (ever) 552.030000.
# episode # 2792.
# exploration eps 0.001000.
# running time 0.111670
# ------------------------------
#
# ------------------------------
# Timestep 4106431.
# mean reward (over 100 episodes) 236.830000.
# best mean reward (ever) 552.030000.
# episode # 2793.
# exploration eps 0.001000.
# running time 0.111301
# ------------------------------
#
# ------------------------------
# Timestep 4107535.
# mean reward (over 100 episodes) 233.740000.
# best mean reward (ever) 552.030000.
# episode # 2794.
# exploration eps 0.001000.
# running time 0.111372
# ------------------------------
#
# ------------------------------
# Timestep 4108645.
# mean reward (over 100 episodes) 233.650000.
# best mean reward (ever) 552.030000.
# episode # 2795.
# exploration eps 0.001000.
# running time 0.111363
# ------------------------------
#
# ------------------------------
# Timestep 4109746.
# mean reward (over 100 episodes) 230.680000.
# best mean reward (ever) 552.030000.
# episode # 2796.
# exploration eps 0.001000.
# running time 0.110523
# ------------------------------
#
# ------------------------------
# Timestep 4110842.
# mean reward (over 100 episodes) 230.650000.
# best mean reward (ever) 552.030000.
# episode # 2797.
# exploration eps 0.001000.
# running time 0.110971
# ------------------------------
#
# ------------------------------
# Timestep 4111944.
# mean reward (over 100 episodes) 227.600000.
# best mean reward (ever) 552.030000.
# episode # 2798.
# exploration eps 0.001000.
# running time 0.111014
# ------------------------------
#
# ------------------------------
# Timestep 4113044.
# mean reward (over 100 episodes) 224.520000.
# best mean reward (ever) 552.030000.
# episode # 2799.
# exploration eps 0.001000.
# running time 0.113394
# ------------------------------
#
# ------------------------------
# Timestep 4114151.
# mean reward (over 100 episodes) 224.450000.
# best mean reward (ever) 552.030000.
# episode # 2800.
# exploration eps 0.001000.
# running time 0.110373
# ------------------------------
#
# ------------------------------
# Timestep 4115256.
# mean reward (over 100 episodes) 221.430000.
# best mean reward (ever) 552.030000.
# episode # 2801.
# exploration eps 0.001000.
# running time 0.111171
# ------------------------------
#
# ------------------------------
# Timestep 4116353.
# mean reward (over 100 episodes) 221.290000.
# best mean reward (ever) 552.030000.
# episode # 2802.
# exploration eps 0.001000.
# running time 0.110589
# ------------------------------
#
# ------------------------------
# Timestep 4117453.
# mean reward (over 100 episodes) 221.300000.
# best mean reward (ever) 552.030000.
# episode # 2803.
# exploration eps 0.001000.
# running time 0.111429
# ------------------------------
#
# ------------------------------
# Timestep 4118557.
# mean reward (over 100 episodes) 221.320000.
# best mean reward (ever) 552.030000.
# episode # 2804.
# exploration eps 0.001000.
# running time 0.111320
# ------------------------------
#
# ------------------------------
# Timestep 4119658.
# mean reward (over 100 episodes) 221.310000.
# best mean reward (ever) 552.030000.
# episode # 2805.
# exploration eps 0.001000.
# running time 0.111859
# ------------------------------
#
# ------------------------------
# Timestep 4120764.
# mean reward (over 100 episodes) 221.310000.
# best mean reward (ever) 552.030000.
# episode # 2806.
# exploration eps 0.001000.
# running time 0.111222
# ------------------------------
#
# ------------------------------
# Timestep 4121872.
# mean reward (over 100 episodes) 221.300000.
# best mean reward (ever) 552.030000.
# episode # 2807.
# exploration eps 0.001000.
# running time 0.111223
# ------------------------------
#
# ------------------------------
# Timestep 4122974.
# mean reward (over 100 episodes) 221.290000.
# best mean reward (ever) 552.030000.
# episode # 2808.
# exploration eps 0.001000.
# running time 0.110851
# ------------------------------
#
# ------------------------------
# Timestep 4124071.
# mean reward (over 100 episodes) 221.300000.
# best mean reward (ever) 552.030000.
# episode # 2809.
# exploration eps 0.001000.
# running time 0.111283
# ------------------------------
#
# ------------------------------
# Timestep 4125175.
# mean reward (over 100 episodes) 218.230000.
# best mean reward (ever) 552.030000.
# episode # 2810.
# exploration eps 0.001000.
# running time 0.111263
# ------------------------------
#
# ------------------------------
# Timestep 4126282.
# mean reward (over 100 episodes) 218.180000.
# best mean reward (ever) 552.030000.
# episode # 2811.
# exploration eps 0.001000.
# running time 0.111597
# ------------------------------
#
# ------------------------------
# Timestep 4127391.
# mean reward (over 100 episodes) 218.230000.
# best mean reward (ever) 552.030000.
# episode # 2812.
# exploration eps 0.001000.
# running time 0.111461
# ------------------------------
#
# ------------------------------
# Timestep 4128498.
# mean reward (over 100 episodes) 215.210000.
# best mean reward (ever) 552.030000.
# episode # 2813.
# exploration eps 0.001000.
# running time 0.110800
# ------------------------------
#
# ------------------------------
# Timestep 4129606.
# mean reward (over 100 episodes) 212.980000.
# best mean reward (ever) 552.030000.
# episode # 2814.
# exploration eps 0.001000.
# running time 0.110658
# ------------------------------
#
# ------------------------------
# Timestep 4130710.
# mean reward (over 100 episodes) 213.050000.
# best mean reward (ever) 552.030000.
# episode # 2815.
# exploration eps 0.001000.
# running time 0.111521
# ------------------------------
#
# ------------------------------
# Timestep 4131822.
# mean reward (over 100 episodes) 213.100000.
# best mean reward (ever) 552.030000.
# episode # 2816.
# exploration eps 0.001000.
# running time 0.112223
# ------------------------------
#
# ------------------------------
# Timestep 4132933.
# mean reward (over 100 episodes) 213.110000.
# best mean reward (ever) 552.030000.
# episode # 2817.
# exploration eps 0.001000.
# running time 0.111962
# ------------------------------
#
# ------------------------------
# Timestep 4134033.
# mean reward (over 100 episodes) 210.150000.
# best mean reward (ever) 552.030000.
# episode # 2818.
# exploration eps 0.001000.
# running time 0.111096
# ------------------------------
#
# ------------------------------
# Timestep 4135143.
# mean reward (over 100 episodes) 207.620000.
# best mean reward (ever) 552.030000.
# episode # 2819.
# exploration eps 0.001000.
# running time 0.111007
# ------------------------------
#
# ------------------------------
# Timestep 4136249.
# mean reward (over 100 episodes) 204.590000.
# best mean reward (ever) 552.030000.
# episode # 2820.
# exploration eps 0.001000.
# running time 0.111101
# ------------------------------
#
# ------------------------------
# Timestep 4137353.
# mean reward (over 100 episodes) 201.630000.
# best mean reward (ever) 552.030000.
# episode # 2821.
# exploration eps 0.001000.
# running time 0.111111
# ------------------------------
#
# ------------------------------
# Timestep 4138457.
# mean reward (over 100 episodes) 201.580000.
# best mean reward (ever) 552.030000.
# episode # 2822.
# exploration eps 0.001000.
# running time 0.111679
# ------------------------------
#
# ------------------------------
# Timestep 4139560.
# mean reward (over 100 episodes) 201.590000.
# best mean reward (ever) 552.030000.
# episode # 2823.
# exploration eps 0.001000.
# running time 0.110909
# ------------------------------
#
# ------------------------------
# Timestep 4140675.
# mean reward (over 100 episodes) 201.570000.
# best mean reward (ever) 552.030000.
# episode # 2824.
# exploration eps 0.001000.
# running time 0.111461
# ------------------------------
#
# ------------------------------
# Timestep 4141776.
# mean reward (over 100 episodes) 201.580000.
# best mean reward (ever) 552.030000.
# episode # 2825.
# exploration eps 0.001000.
# running time 0.111440
# ------------------------------
#
# ------------------------------
# Timestep 4142885.
# mean reward (over 100 episodes) 198.490000.
# best mean reward (ever) 552.030000.
# episode # 2826.
# exploration eps 0.001000.
# running time 0.111239
# ------------------------------
#
# ------------------------------
# Timestep 4143985.
# mean reward (over 100 episodes) 198.460000.
# best mean reward (ever) 552.030000.
# episode # 2827.
# exploration eps 0.001000.
# running time 0.110883
# ------------------------------
#
# ------------------------------
# Timestep 4145089.
# mean reward (over 100 episodes) 198.440000.
# best mean reward (ever) 552.030000.
# episode # 2828.
# exploration eps 0.001000.
# running time 0.110323
# ------------------------------
#
# ------------------------------
# Timestep 4146186.
# mean reward (over 100 episodes) 198.310000.
# best mean reward (ever) 552.030000.
# episode # 2829.
# exploration eps 0.001000.
# running time 0.111451
# ------------------------------
#
# ------------------------------
# Timestep 4147289.
# mean reward (over 100 episodes) 198.280000.
# best mean reward (ever) 552.030000.
# episode # 2830.
# exploration eps 0.001000.
# running time 0.111595
# ------------------------------
#
# ------------------------------
# Timestep 4148392.
# mean reward (over 100 episodes) 195.220000.
# best mean reward (ever) 552.030000.
# episode # 2831.
# exploration eps 0.001000.
# running time 0.113818
# ------------------------------
